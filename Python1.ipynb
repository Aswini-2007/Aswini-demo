# %% [markdown]
# <a href="https://colab.research.google.com/github/Aswini-2007/Aswini-demo/blob/main/Copy_of_Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello world')
# Out:
# Hello world

# %%
print('Name : K Aswini')
print('Course : Data Science')
print('Welcome to India')
print('State : Telangana')
print('Address : ECIL')
print('Studying : BTech')
print('Schooling : Seventh Day Adventist High School')
print('Inter : Fiitjee Junior college')
print('BTech : CSE Core')
print('Qualification : Student')
print('Year / Semester : 2nd year 1st semester')
print('College : ABC Engineering College')
print('University : JNTUH')
print('Country : India')
print('Nationality : Indian')
print('Gender : Female')
print('Age : 19')
print('Hobby : Reading Books')
print('Hobby : Listening to Music')
print('Hobby : Coding')
print('Favorite Subject : Python')
print('Favorite Language : English')
print('Favorite Sport : Badminton')
print('Favorite Color : Blue')
print('Favorite Food : Biryani')
print('Favorite Place : Hyderabad')
print('Goal : Data Scientist')
print('Programming Language : Python')
print('Programming Language : Java')
print('Programming Language : C')
print('Database : MySQL')
print('Operating System : Windows')
print('Skill : Problem Solving')
print('Skill : Communication')
print('Skill : Team Work')
print('Skill : Critical Thinking')
print('Project : Student Management System')
print('Project : Timetable Scheduling System')
print('Certification : Python Basics')
print('Certification : Data Analytics')
print('Strength : Hard Working')
print('Strength : Quick Learner')
print('Strength : Self Motivated')
print('Weakness : Overthinking')
print('Dream Company : Google')
print('Dream Company : Microsoft')
print('Dream Company : Amazon')
print('Current Status : Learning Data Science')
print('Career Objective : Become a Data Scientist')
print('Learning : Machine Learning')
print('Thank You')
# Out:
# Name : K Aswini
# Course : Data Science
# Welcome to India
# State : Telangana
# Address : ECIL
# Studying : BTech
# Schooling : Seventh Day Adventist High School
# Inter : Fiitjee Junior college
# BTech : CSE Core
# Qualification : Student
# Year / Semester : 2nd year 1st semester
# College : ABC Engineering College
# University : JNTUH
# Country : India
# Nationality : Indian
# Gender : Female
# Age : 19
# Hobby : Reading Books
# Hobby : Listening to Music
# Hobby : Coding
# Favorite Subject : Python
# Favorite Language : English
# Favorite Sport : Badminton
# Favorite Color : Blue
# Favorite Food : Biryani
# Favorite Place : Hyderabad
# Goal : Data Scientist
# Programming Language : Python
# Programming Language : Java
# Programming Language : C
# Database : MySQL
# Operating System : Windows
# Skill : Problem Solving
# Skill : Communication
# Skill : Team Work
# Skill : Critical Thinking
# Project : Student Management System
# Project : Timetable Scheduling System
# ...

# %%
#variable
#variable
name = 'Aswini'
print(name)

# Rule : 1 Number cannot be used as variable names
# 10 = 10
# print(10)

# Rule : 2  Variables are case sensitive
a = 10
#print(A)

# Rule : 3 Special symbols are not allowed
# * = 10
# print(*)

# Rule : 4 Space is not allowed in variable
first_name = "Aswini"
print(first_name)

# Rule : 5 variable names should not start with numbers
a1 = 10
print(a1)

# Rule 6 : Keywords are not used in variable names
for = "hello"
print(for)
# Out:
#   File "/tmp/ipykernel_900/4203810192.py", line 27
#     for = "hello"
#         ^
# SyntaxError: invalid syntax

# %%
a = [11,13, "apple",0.009,45,10]
print(a)
print(type(a))

a = {11,13,"apple",0.009,45,10}
print(a)
print(type(a))

a = [11,13,"apple", 0.009,45,10]
print(a)
print(type(a))
print('....................indexing..............')
print(a[2])
print(a[-2])
print(a[0 : 3])
print(a[:: -1])

print('...........slicing.................')
a.append(33)
print(a)
a.insert(3,'cat')
print(a)
a.remove('apple')
print(a)
a.pop(2)
print(a)
a.sort()
print(a)
a.sort(reverse=True)
print(a)
print(max(a))
print(min(a))
print(len(a))
print(sum(a))
print(a.count(10))
print(a.index(10))
a.reverse()
print(a)

a = [11,13,"apple", 0.009,45,10]
print(a)
print(type(a))
print('....................indexing..............')
print(a[2])
print(a[-2])
print(a[0 : 3])
print(a[:: -1])

print('...........converting tuple to list.............')
a = list(a)
print(a)

print('...........slicing.................')
a.append(33)
print(a)
a.insert(3,'cat')
print(a)
a.remove('apple')
print(a)
a.pop(2)
print(a)
a.sort()
print(a)
a.sort(reverse=True)
print(a)
print(max(a))
print(min(a))
print(len(a))
print(sum(a))
print(a.count(10))
print(a.index(10))
a.reverse()
print(a)
a.clear()
print(a)

print('............converting list to tuple...........')
a = list(a)
print(a)

a = [11,13,"apple", 0.009,45,10]
print(a)
print(type(a))


print('....................indexing..............')
print(a[2])
print(a[-2])
print(a[0 : 3])
print(a[:: -1])

print('...........converting set to list.............')
a = list(a)
print(a)

print('...........slicing.................')
a.append(33)
print(a)
a.insert(3,'cat')
print(a)
a.remove('apple')
print(a)
a.pop(2)
print(a)
a.sort()
print(a)
a.sort(reverse=True)
print(a)
print(max(a))
print(min(a))
print(len(a))
print(sum(a))
print(a.count(10))
print(a.index(10))
a.reverse()
print(a)
a.clear()
print(a)
# sets dont allow duplicates
print('............converting list to set...........')
a = list(a)
print(a)

a = {11,12,13,"apple"}
b = {12,13,"banana"}
c = a.union(b)
print(c)
c = a.intersection(b)
print(c)
c = a.difference(b)
print(c)

c = a.symmetric_difference(b)
print(c)

# d = [1,2,3]
# e = a.union(d)
# print(e)

a = 10
b = "apple"
c = 1.321
print(a,b,c)

dic = {'a' : 10, 'b' : "apple", 'c' : 1.321, 3 : "orange"}
print(type(dic))

print('........indexing..........')
print()

dic = {'a' : 10, 'b' : "apple", 'c' : 1.321, 3 : "orange"}
print(dic)
print(type(dic))

print('........indexing..........')
print(dic['a'])
print(dic[3])

print('.........slicing............')
print(dic.keys())
print(dic.values())
print(dic.items())
print(len(dic))

dic['color'] = "Red"
print(dic)

dic['c'] = 0.0001
print(dic)
# remove
dic.pop(3)
print(dic)
dic.popitem()
print(dic)
dic.clear()
print(dic)

# dic = dictionary
student = {'Name' : "Ghost", 'std' : 2, 'age' : 8}
student = {'Name' : "God", 'std' : 2, 'age' : 9}
print(student)

cls = {
    'Ghost' :{'std' : 2, 'age' : 8},
    'God' :{'std': 2, 'age': 9}
}
print(cls)
print(cls['Ghost'])
print(cls['Ghost']['age'])
# Out:
# [11, 13, 'apple', 0.009, 45, 10]
# <class 'list'>
# {'apple', 13, 10, 11, 0.009, 45}
# <class 'set'>
# [11, 13, 'apple', 0.009, 45, 10]
# <class 'list'>
# ....................indexing..............
# apple
# 45
# [11, 13, 'apple']
# [10, 45, 0.009, 'apple', 13, 11]
# ...........slicing.................
# [11, 13, 'apple', 0.009, 45, 10, 33]
# [11, 13, 'apple', 'cat', 0.009, 45, 10, 33]
# [11, 13, 'cat', 0.009, 45, 10, 33]
# [11, 13, 0.009, 45, 10, 33]
# [0.009, 10, 11, 13, 33, 45]
# [45, 33, 13, 11, 10, 0.009]
# 45
# 0.009
# 6
# 112.009
# 1
# 4
# [0.009, 10, 11, 13, 33, 45]
# [11, 13, 'apple', 0.009, 45, 10]
# <class 'list'>
# ....................indexing..............
# apple
# 45
# [11, 13, 'apple']
# [10, 45, 0.009, 'apple', 13, 11]
# ...........converting tuple to list.............
# [11, 13, 'apple', 0.009, 45, 10]
# ...........slicing.................
# [11, 13, 'apple', 0.009, 45, 10, 33]
# [11, 13, 'apple', 'cat', 0.009, 45, 10, 33]
# [11, 13, 'cat', 0.009, 45, 10, 33]
# ...

# %%
#sets are immuitable
a = "india is my country"
print(a)
print(type(a))

print('..............indexing................')
print(a[0])
print(a[-1])
print(a[1 : 12])
print(a[:: -1])

print('............methods.............')
print(a.capitalize())
print(a.upper())
print(a.lower())
print(a.count('i'))
print(a.find('r'))

b = "Rahul said"
print(a+b)

print(f"{b}, that, {a}")
# Out:
# india is my country
# <class 'str'>
# ..............indexing................
# i
# y
# ndia is my
# yrtnuoc ym si aidni
# ............methods.............
# India is my country
# INDIA IS MY COUNTRY
# india is my country
# 3
# 17
# india is my countryRahul said
# Rahul said, that, india is my country

# %%
#operators
#arthematic + - * / // ** %

a = 3
b = 2
print(a+b)#5
print(a-b)#1
print(a*b)#6
print(a/b)#1.5
print(a//b)#1.5 = 1 (only yhe integer value)
print(a%b)#1(remainder)
print(a**b)#9(3 * 3)

# %%
#relational or comparison >< .= <= == !=

print(a>b)
print(a<b)
print(a>=b)
print(a<=b)
print(a==b)
print(a!=b)
# Out:
# True
# False
# True
# False
# False
# True

# %%
# Logical and or not

print(a>b and a!=b)
print(a>b or a==b)
print(not (a>b))
# Out:
# True
# True
# False

# %%
# membership in , not in

a = [11,12,"Hello", "bat"]
b = "Hello"

print(b in a)
print(b not in a)
# Out:
# True
# False

# %%
# identity is , is not

a = 12
b = 12
print(a is b)
print(a is not b)
print(id(a))
print(id(b))
# Out:
# True
# False
# 11645704
# 11645704

# %%
# assignment operater art=

a = 2
a += 3 # a= a+3
a -= 1 #4
a *= 3 #12
a /= 2 #6
a ** 3 #216
a %= 2 2#0
print(a)
# Out:
# 0.0

# %%
# bitwise operator

a = 7
b = 5
print(a&b)
print(a|b)
print(a^b)
print(a, ~b)
# Out:
# 5
# 7
# 2
# 7 -6

# %%
#walrus (important) a := 2
#its one of assignment operator
a = [12,11,13]
print(len(a))
a.pop(-1)
print(a)

while(b:= len(a)) !=0:
  print(a.pop(-1))
# Out:
# 3
# [12, 11]
# 11
# 12

# %%
from ast import Expression
a = [12,11,13]
# variable : Expression
while(b:= len(a)) !=0:

  print(a.pop(-1))
# Out:
# 13
# 11
# 12
